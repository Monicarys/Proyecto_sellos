# %%
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import random
import pickle
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.decomposition import PCA

# %%
DATADIR = 'Sellos/' ##En este folder tengo los folders de mis imágenes
Categories = ['Dado', 'Dardo', 'Foco', 'Maceta', 'Oso', 'Pulpo', 'Rueda']##Estos son los nombres de cada folder con imágenes
for category in Categories:
    path = os.path.join(DATADIR, category)
    for img in os.listdir(path):
        img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)##Obtener matrices de las imágenes
        img_Vec = (np.asarray(img_array)).flatten()##Convertir en vectores las matrices
        plt.imshow(img_array, cmap='gray')
        plt.show()
        break
    break

# %%
img_array.shape
# Out:
# (147, 148)

# %%
IMG_SIZE=140
new_array=cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))##Hago que todas las imágenes tengan el mismo tamaño 140x140
plt.imshow(new_array,cmap='gray')

# %%
training_data = []

def create_training_data():
    for category in Categories:
        path = os.path.join(DATADIR, category)
        class_num = Categories.index(category)
        for img in os.listdir(path):
            try:
                img_array = cv2.imread(os.path.join(path,img), cv2.IMREAD_GRAYSCALE)
                img_N_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
                img_Vec = (np.asarray(img_N_array)).flatten()
                training_data.append([img_N_array,img_Vec, class_num])
            except Exception as e:
                pass
##sea crea el dataset con tres partes en cada entrada,
##[la matriz para poder imprimir la imágen, el vector con el que quiero usar KNN, la etiqueta que me dice a cual de las imágenes pertenece]            
create_training_data()

# %%
random.shuffle(training_data)

# %%
#training_data

# %%
Z=[]##Para guardar las matrices
X=[]##Para guardar los vectores
y=[]##Para guardar las etiquetas


for image, features, label in training_data:
    Z.append(image) 
    X.append(features)
    y.append(label)

# %%
#Guardo todo para no tener que hacer lo anterior otra vez
pickle_out = open('X.pickle','wb')
pickle.dump(X, pickle_out)
pickle_out.close()

pickle_out = open('y.pickle','wb')
pickle.dump(y, pickle_out)
pickle_out.close()

pickle_out = open('Z.pickle','wb')
pickle.dump(Z, pickle_out)
pickle_out.close()

# %%
pickle_in = open('X.pickle','rb')
X = pickle.load(pickle_in)
pickle_in = open('y.pickle','rb')
y = pickle.load(pickle_in)
pickle_in = open('Z.pickle','rb')
Z = pickle.load(pickle_in)

# %%
# Divido entre datos de entrenamiento y de prueba
X_train, X_test, y_train, y_test, Z_train, Z_test = train_test_split(X, y, Z, stratify=y, random_state=0)

# %%
#X

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
knn.score(X_test, y_test)
# Out:
# 0.9672131147540983

# %%
X_test
# Out:
# [array([252, 249, 251, ..., 253, 253, 253], dtype=uint8),
#  array([210, 217, 213, ..., 254, 232, 226], dtype=uint8),
#  array([252, 252, 249, ..., 253, 253, 253], dtype=uint8),
#  array([223, 251, 249, ..., 254, 242, 187], dtype=uint8),
#  array([222, 225, 224, ..., 243, 242, 242], dtype=uint8),
#  array([255, 255, 255, ..., 222, 224, 226], dtype=uint8),
#  array([164, 194, 203, ..., 208, 209, 211], dtype=uint8),
#  array([249, 249, 251, ..., 249, 248, 249], dtype=uint8),
#  array([199, 185, 179, ..., 188, 180, 182], dtype=uint8),
#  array([253, 253, 253, ..., 251, 248, 250], dtype=uint8),
#  array([250, 249, 249, ..., 215, 215, 219], dtype=uint8),
#  array([219, 218, 213, ..., 246, 251, 233], dtype=uint8),
#  array([191, 253, 254, ..., 238, 244, 222], dtype=uint8),
#  array([222, 238, 239, ..., 254, 247, 236], dtype=uint8),
#  array([187, 188, 152, ..., 255, 253, 253], dtype=uint8),
#  array([246, 248, 251, ..., 239, 240, 244], dtype=uint8),
#  array([171, 177, 190, ..., 252, 251, 220], dtype=uint8),
#  array([247, 253, 244, ..., 252, 253, 253], dtype=uint8),
#  array([250, 250, 250, ..., 239, 239, 239], dtype=uint8),
#  array([182, 181, 200, ..., 210, 209, 208], dtype=uint8),
#  array([206, 222, 228, ..., 209, 221, 218], dtype=uint8),
#  array([255, 248, 216, ..., 247, 253, 215], dtype=uint8),
#  array([199, 186, 204, ..., 244, 229, 193], dtype=uint8),
#  array([253, 253, 253, ..., 249, 251, 252], dtype=uint8),
#  array([170, 170, 167, ..., 213, 214, 205], dtype=uint8),
#  array([253, 252, 248, ..., 203, 202, 202], dtype=uint8),
#  array([217, 237, 249, ..., 220, 229, 245], dtype=uint8),
#  array([231, 229, 222, ..., 245, 246, 247], dtype=uint8),
#  array([241, 244, 241, ..., 238, 241, 241], dtype=uint8),
#  array([251, 253, 251, ..., 247, 250, 252], dtype=uint8),
#  array([254, 253, 253, ..., 251, 250, 245], dtype=uint8),
#  array([197, 210, 201, ..., 233, 209, 254], dtype=uint8),
#  array([218, 216, 220, ..., 254, 254, 254], dtype=uint8),
#  array([189, 222, 251, ..., 181, 189, 169], dtype=uint8),
#  array([252, 232, 181, ..., 255, 255, 255], dtype=uint8),
#  array([254, 255, 250, ..., 253, 253, 251], dtype=uint8),
#  array([249, 253, 252, ..., 253, 253, 253], dtype=uint8),
#  array([249, 195, 250, ..., 243, 246, 205], dtype=uint8),
#  array([219, 246, 240, ..., 249, 195, 216], dtype=uint8),
#  array([252, 253, 252, ..., 253, 253, 251], dtype=uint8),
#  array([225, 247, 253, ..., 255, 249, 200], dtype=uint8),
#  array([203, 204, 205, ..., 253, 253, 254], dtype=uint8),
#  array([198, 249, 255, ..., 254, 254, 255], dtype=uint8),
#  array([252, 252, 252, ..., 249, 250, 250], dtype=uint8),
#  array([246, 251, 254, ..., 229, 226, 222], dtype=uint8),
#  array([195, 251, 253, ..., 228, 234, 199], dtype=uint8),
#  array([249, 248, 231, ..., 248, 252, 249], dtype=uint8),
#  array([245, 249, 252, ..., 246, 248, 162], dtype=uint8),
#  array([223, 221, 219, ..., 247, 247, 247], dtype=uint8),
#  array([253, 253, 253, ..., 251, 250, 251], dtype=uint8),
#  array([208, 217, 223, ..., 225, 225, 224], dtype=uint8),
#  array([229, 229, 235, ..., 253, 253, 253], dtype=uint8),
#  array([254, 255, 254, ..., 231, 234, 235], dtype=uint8),
#  array([254, 255, 252, ..., 250, 253, 254], dtype=uint8),
#  array([252, 246, 245, ..., 253, 253, 253], dtype=uint8),
#  array([255, 253, 255, ..., 240, 239, 238], dtype=uint8),
#  array([254, 249, 252, ..., 253, 253, 253], dtype=uint8),
#  array([242, 246, 250, ..., 239, 237, 233], dtype=uint8),
#  array([249, 228, 184, ..., 188, 200, 158], dtype=uint8),
#  array([231, 234, 236, ..., 238, 243, 243], dtype=uint8),
#  array([249, 191, 140, ..., 251, 251, 250], dtype=uint8)]

# %%
X_test.iloc(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-b8abd4ffcddb> in <module>
# ----> 1 X_test.iloc(0)
#
# AttributeError: 'list' object has no attribute 'iloc'

# %%
X[1].shape
# Out:
# (19600,)

# %%
len(X_train)
# Out:
# 181

# %%
from sklearn.decomposition import NMF
# Decimos cuantas componentes queremos y damos la semilla aleatoria
nmf = NMF(n_components=10, random_state=0)
# Decimos con respecto a que conjunto hacer el ajuste
nmf.fit(X_train)
# Transformamos los datos de entrenamiento y prueba
X_train_nmf = nmf.transform(X_train)
X_test_nmf = nmf.transform(X_test)
# Out:
# C:\Users\David\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:312: FutureWarning: The 'init' value, when 'init=None' and n_components is less than n_samples and n_features, will be changed from 'nndsvd' to 'nndsvda' in 1.1 (renaming of 0.26).
#   warnings.warn(("The 'init' value, when 'init=None' and "
# C:\Users\David\anaconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1090: ConvergenceWarning: Maximum number of iterations 200 reached. Increase it to improve convergence.
#   warnings.warn("Maximum number of iterations %d reached. Increase it to"

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train_nmf, y_train)
knn.score(X_test_nmf, y_test)
# Out:
# 0.9672131147540983

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
knn = KNeighborsClassifier(n_neighbors=1)
knn.fit(X_train_scaled, y_train)
knn.score(X_test_scaled, y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC
svm = SVC(C=100)
# Entrenamos al modelo con los datos de entrenamiento escalados
svm.fit(X_train_scaled, y_train)
# Imprimimos el porcentaje de acierto aplicar el método al conjunto de prueba escalado
svm.score(X_test_scaled, y_test)
# Out:
# 0.9016393442622951

# %%
X_test[0:3]
# Out:
# [array([252, 249, 251, ..., 253, 253, 253], dtype=uint8),
#  array([210, 217, 213, ..., 254, 232, 226], dtype=uint8),
#  array([252, 252, 249, ..., 253, 253, 253], dtype=uint8)]

# %%
plt.imshow(Z_test[0],cmap='gray')

# %%
y_test[0:3]
# Out:
# [1, 4, 1]

# %%
X_new_test=X_test[0:1]

# %%
X_new_test
# Out:
# [array([252, 249, 251, ..., 253, 253, 253], dtype=uint8)]

# %%
y_new_test=y_test[0:1]

# %%
y_new_test
# Out:
# [1]

# %%
knn.score(X_new_test, y_new_test)
# Out:
# 0.0

# %%
###Esto se deberia reparar

for i in range(6):
    X_new_test=X_test[i:i+1]
    y_new_test=y_test[i:i+1]
    knn.score(X_new_test, y_new_test)
    print(':________________-')
# Out:
# :________________-
# :________________-
# :________________-
# :________________-
# :________________-
# :________________-
